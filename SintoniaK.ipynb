# %%
import numpy as np
import pygad as pyAG
import control as ct
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import animation, rc
from control.matlab import *
from control import matlab
from mpl_toolkits.mplot3d import axes3d
from pylab import *
from IPython.display import HTML
from control import place
from scipy import integrate


plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams.update({'font.size': 18})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 import pygad as pyAG
#       3 import control as ct
#       4 import matplotlib.pyplot as plt
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pygad\__init__.py:1
# ----> 1 from .pygad import * # Relative import.
#       3 __version__ = "2.18.1"
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pygad\pygad.py:9
#       6 import warnings
#       7 import concurrent.futures
# ----> 9 class GA:
#      11     supported_int_types = [int, numpy.int, numpy.int8, numpy.int16, numpy.int32, numpy.int64, numpy.uint, numpy.uint8, numpy.uint16, numpy.uint32, numpy.uint64]
#      12     supported_float_types = [float, numpy.float, numpy.float16, numpy.float32, numpy.float64]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pygad\pygad.py:11, in GA()
#       9 class GA:
# ---> 11     supported_int_types = [int, numpy.int, numpy.int8, numpy.int16, numpy.int32, numpy.int64, numpy.uint, numpy.uint8, numpy.uint16, numpy.uint32, numpy.uint64]
#      12     supported_float_types = [float, numpy.float, numpy.float16, numpy.float32, numpy.float64]
#      13     supported_int_float_types = supported_int_types + supported_float_types
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\__init__.py:284, in __getattr__(attr)
#     281     from .testing import Tester
#     282     return Tester
# --> 284 raise AttributeError("module {!r} has no attribute "
#     285                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'int'
